# %%
# build a database from a dataset for nomenclating
# INPUT: a collection of GAIN domain PDBs, their sequences as one large ".fa" file
from gain_classes import GainDomain, GainCollection, Anchors, GPS
import sse_func
import execute
import numpy as np
import glob
import multiprocessing as mp
from subprocess import Popen, PIPE

# %%
# The Goal is to create a GainCollection from all GAIN domains here
# The set of proteins needs to be filtered and analyzed statistically before

# Example PDB name:
#  R0LVI9-R0LVI9_ANAPL-PutativeGR125-Anas_platyrhynchos_unrelaxed_rank_1_model_3.pdb
# corresponding STRIDE name:
#  R0LVI9-R0LVI9_ANAPL-PutativeGR125-Anas_platyrhynchos.stride
pdbs = glob.glob("/home/flo/projects/agpcr_nom/*/batch*/*_rank_1_*.pdb")
print(f"Found {len(pdbs)} best ranked models in target directories.")
# Out:
# Found 15839 best ranked models in target directories.

# %%
stride_folder = f"./all_gps_stride"
stride_bin = "/home/hildilab/lib/stride/stride"
           
def compile_stride_mp_list(pdbs, stride_folder,stride_bin):
    stride_mp_list = []
    
    for pdb in pdbs:
        pdb_name = pdb.split("/")[-1]
        name = pdb_name.split("_unrelaxed_")[0]
        out_file = f"{stride_folder}/{name}.stride"
        arg = [pdb, out_file, stride_bin]
        
        stride_mp_list.append(arg)
        
    return stride_mp_list

def run_stride(arg):
    pdb_file, out_file, stride_bin = arg
    stride_command = f"{stride_bin} {pdb_file} -f{out_file}"
    execute.run_command(stride_command)

def execute_stride_mp(stride_mp_list, n_threads=10):
        stride_pool = mp.Pool(n_threads)
        stride_pool.map(run_stride, stride_mp_list)
        print("Completed mutithreaded creation of STRIDE files!")
        
        #execute.run_stride(pdb, out_file, stride_bin)

# %%
"""stride_mp_list = compile_stride_mp_list(pdbs, stride_folder, stride_bin)
stride_mp_list = compile_stride_mp_list(singlet_pdbs, stride_folder, stride_bin)
print(len(stride_mp_list))
[print(arg) for arg in stride_mp_list[:10]]"""
# Out:
# 'stride_mp_list = compile_stride_mp_list(pdbs, stride_folder, stride_bin)\nstride_mp_list = compile_stride_mp_list(singlet_pdbs, stride_folder, stride_bin)\nprint(len(stride_mp_list))\n[print(arg) for arg in stride_mp_list[:10]]'

# %%
# MP execution of STRIDE
#execute_stride_mp(stride_mp_list, n_threads=30)

# %%
# Eliminate double entries (both in the original run and the added small runs)
# Form the "pdbs" list

stride_files = glob.glob("/home/flo/projects/agpcr_nom/all_gps_stride/*")
accessions = [f.split(".strid")[0].split("/")[-1] for f in stride_files]
pdb_accessions = np.array([p.split("_unrelaxed_")[0].split("/")[-1] for p in pdbs])

# Find duplicate in the original pdbs list and indicate them via > is_duplicate = True <
is_duplicate=np.zeros([len(pdbs)], dtype=bool)
sort_pdb_ac = np.sort(pdb_accessions)
duplicate_list = []
for i, pdb in enumerate(sort_pdb_ac):
    if i+1 == len(sort_pdb_ac):
        break
    if pdb == sort_pdb_ac[i+1]:
        duplicate_list.append(pdb)
        multi_indices = np.where(pdb == pdb_accessions)[0]
        is_duplicate[multi_indices[0]] = True

np_pdbs = np.array(pdbs)
singlet_pdbs = np_pdbs[is_duplicate == False] # This is the reduced list with ONLY UNIQUE PDBs
print(f"Reduced the initial set of {len(pdbs)} PDB files down to {len(singlet_pdbs)} files.")


# This is a check routine if there are PDBs in the reduced list which have NOT a STRIDE file
singlet_pdb_accessions = np.array([p.split("_unrelaxed_")[0].split("/")[-1] for p in singlet_pdbs])

counter = 0
for ac in singlet_pdb_accessions:
    if ac not in accessions:
        print(ac)
    else:
        counter += 1
print(f"Found {counter}/{len(singlet_pdb_accessions)} accessions in the accession list.")
# Out:
# Reduced the initial set of 15839 PDB files down to 14773 files.
# Found 14773/14773 accessions in the accession list.

# %%
"""stride_folder = f"{pdb_folder}/stride_files"
fasta_file = "/home/hildilab/projects/agpcr_nom/batch_files/batch_60.fa"
# CHECK FILES!
import os
if not os.path.isfile(fasta_file) or os.path.islink(fasta_file):
    print("ERROR: Specify FASTA FILE CONTAINING ALL SEQUENCES OF THE PROTEINS!")
    
    
alignment_file = "/home/hildilab/projects/agpcr_nom/batch_out_test/mafft.fa"
#alignment_file = None

# If there is not a specified base alignment, create one (that might take a while tho.)
if not alignment_file:
    mafft_bin = "mafft"
    mafft_command = f"{mafft_bin} --auto --thread 4 {fasta_file}"
    out_dir = "/".join(fasta_file.split("/")[:-2])
    out_file = f"{out_dir}/mafft.fa"
    execute.run_command(mafft_command, out_file = out_file)
    alignment_file = out_file
gps_minus_one_column = 1209"""
# Out:
# 'stride_folder = f"{pdb_folder}/stride_files"\nfasta_file = "/home/hildilab/projects/agpcr_nom/batch_files/batch_60.fa"\n# CHECK FILES!\nimport os\nif not os.path.isfile(fasta_file) or os.path.islink(fasta_file):\n    print("ERROR: Specify FASTA FILE CONTAINING ALL SEQUENCES OF THE PROTEINS!")\n    \n    \nalignment_file = "/home/hildilab/projects/agpcr_nom/batch_out_test/mafft.fa"\n#alignment_file = None\n\n# If there is not a specified base alignment, create one (that might take a while tho.)\nif not alignment_file:\n    mafft_bin = "mafft"\n    mafft_command = f"{mafft_bin} --auto --thread 4 {fasta_file}"\n    out_dir = "/".join(fasta_file.split("/")[:-2])\n    out_file = f"{out_dir}/mafft.fa"\n    execute.run_command(mafft_command, out_file = out_file)\n    alignment_file = out_file\ngps_minus_one_column = 1209'

# %%
# The GainCollection class needs to be modified to also parse a list of sequences 
# instead of a folder containing one fasta per seq
class FilterCollection:
    ''' 
    A collection of GainDomain objects used for filtering a set of AF2 models
    This is used to condense the dataset towards one containing only GAIN domains

    Attributes
    ----------

    collection : list
        List of GainDomain instances
   
    valid_gps : np.array(bool)
        For each protein, specify if the GPS detection is valid or not
    
    valid_subdomain : np.array(bool)
        For each protein, specify if it has detected subdomains or not
    
    Methods
    ----------
    print_gps(self):
        Prints info about all GainDomain GPS subinstances

    write_all_seq(self, savename):
        Writes all sequences in the Collection to one file

    transform_alignment(self, input_alignment, output_alignment, aln_cutoff):
        Transforms a given alignment with SSE data to a SSE-assigned version of the alignment
        
    write_filtered(self, savename, bool_mask):
        Writes all sequences to File where a boolean mask (i.e. subdomain_criterion, gps_criterion)
        is True at respective position
    '''
    def __init__(self,
                alignment_file, 
                aln_cutoff,
                quality,
                gps_index,
                stride_files,
                sequence_files=None, # modified to object containing all seqs
                sequences=None, # replaces sequence_files
                subdomain_bracket_size=20,
                domain_threshold=20,
                coil_weight=0,
                alignment_dict=None): 
        '''
        Constructs the GainCollection objects by initializing one GainDomain instance per given sequence
        
        Parameters
        ----------
        alignment_file:     str, required
            The base dataset alignment file

        aln_cutoff:         int, required
            Integer value of last alignment column

        quality:            list, required
            List of quality valus for each alignment column. Has to have $aln_cutoff items
            By default, would take in the annotated Blosum62 values from the alignment exported from Jalview

        gps_index:          int, required
            Alignment column index of the GPS-1 residue (consensus: Leu)
        
        stride_files:       list, required
            A list of stride files corresponding to the sequences contained within.
        
        sequence_files:     list, optional
            A list of sequence files to be read as the collection - specify either this
            or sequences as an object instead of files for sequences
        
        sequences:          object, optional
            A list of (sequence_name, sequence) tuples containing all sequences. Can be specified
            instead of sequence_files

        subdomain_bracket_size: int, optional
            Smoothing window size for the signal convolve function. Default = 20.

        domain_threshold:   int, optional
            Minimum size of a helical segment to be considered candidate for Subdomain A of GAIN domain. Default = 20.

        coil_weight:        float, optional
            Weight assigned to unordered residues during Subdomain detection. Enables decay of helical signal
            default = 0. Recommended values < +0.2 for decay

        Returns
        ----------
        None
        '''
        # Initialize collection (containing all GainDomain instances) and the anchor-histogram
        if sequence_files:
            # Compile all sequence files to a sequences object
            sequences = np.empty([len(sequence_files)])
            for i, seq_file in enumerate(sequence_files):
                name, seq = read_seq(seq_file, return_name = True)
                sequences[i] = (name, seq)
        elif (sequences is not None):
            print(f"Found sequences object.")
        else: 
            print(f"ERROR: no sequence_files or sequences parameter found. Aborting compilation.")
            return None
        self.collection = np.empty([len(sequences)], dtype=object)
        
        valid_gps = np.zeros([len(sequences)], dtype=bool)
        valid_subdomain = np.zeros([len(sequences)], dtype=bool)
        #anchor_hist = np.zeros([aln_cutoff])#
        # Create a GainDomain instance for each sequence file contained in the list
        for i,seq_tup in enumerate(sequences):
            # updated GainDomain class
            name, sequence = seq_tup
            explicit_stride = [stride for stride in stride_files if name.split("-")[0] in stride]
            if len(explicit_stride) == 0:
                print(f"Stride file not found for {name}")
            newGain = GainDomain(alignment_file, 
                                  aln_cutoff,
                                  quality,
                                  name = name,
                                  sequence = sequence,
                                  gps_index = gps_index, 
                                  subdomain_bracket_size = subdomain_bracket_size,
                                  domain_threshold = domain_threshold,
                                  coil_weight = coil_weight,
                                  explicit_stride_file = explicit_stride[0],
                                  without_anchors = True,
                                  skip_naming = True,
                                  alignment_dict = alignment_dict)

            # Check if the object staisfies minimum criteria
            if newGain.isValid: 
                  
                self.collection[i] = newGain
                  
                if newGain.hasSubdomain:
                    valid_subdomain[i] = True
                if newGain.GPS.isConsensus:
                    valid_gps[i] = True
        
        self.valid_subdomain = valid_subdomain
        self.valid_gps = valid_gps
        print(f"Completed Collection initialitazion of {len(sequences)} sequences.\n"
             f"{np.count_nonzero(self.collection)} valid proteins were found.\n"
             f"{np.count_nonzero(self.valid_subdomain)} of which have detected Subdomains.\n"
             f"{np.count_nonzero(self.valid_gps)} of which have detected consensus GPS motifs.\n")

    def print_gps(self):
        '''
        Prints information about the GPS of each GAIN domain.

        Parameters:
            None
        Returns:
            None
        '''
        for i, gain in enumerate(self.collection):
            try:
                gain.GPS.info()
            except:
                print(f"No GPS data for {gain.name}. Likely not a GAIN Domain!")

    def write_all_seq(self, savename):
        '''
        Write all GAIN sequences of the GainCollection into one fasta file.

        Parameters
        ----------
        savename: str, required
            Output name of the fasta file.

        Returns
        ----------
        None
        '''
        with open(savename, 'w') as f:
            for gain in self.collection:
                f.write(f">{gain.name[:-3]}\n{''.join(gain.sequence)}\n")
    
    def write_filtered(self, savename, bool_mask=None, write_mode='w'):
                  
        '''
        Internal function for writing filtered sequences to file.
        Takes the Gain.sequence np.array type to write the truncated versions.
        
        Parameters
        ----------
        savename: str, required
            Output name of the fasta file.
        bool_mask: list/array, required
            A mask of len(self.collection) where a boolean defines whether to write the
            sequence to file or not
        Returns
        ----------
        None
        '''
        with open(savename, write_mode) as f:
            print(f"writing filtered to {savename}")
            for i, gain in enumerate(self.collection):
                if gain is not None and bool_mask[i] == True:
                    f.write(f">{gain.name.replace('.fa','')}\n{''.join(gain.sequence)}\n")

    def transform_alignment(self, input_alignment, output_alignment, aln_cutoff):
        ''' 
        Transform any input alignment containing all sequences in the GainCollection 
        into one where each residue is replaced with the respective 
        Secondary Structure from the STRIDE files

        Parameters
        ----------
        input_alignment: str, required
            Input alignment file
        output_alignment: str, required
            Output alignment file
        aln_cutoff: int, required
            Last alignment column to be read from the Input Alignment

        Returns
        ---------
        None
        '''
        initial_dict = sse_func.read_alignment(input_alignment, aln_cutoff)
        out_dict = {}
        for gain in self.collection:
            sse_alignment_row = np.full([aln_cutoff], fill_value='-', dtype='<U1')
            mapper = sse_func.get_indices(gain.name, gain.sequence, input_alignment, aln_cutoff)
            for index, resid in enumerate(gain.sse_sequence):
                sse_alignment_row[mapper[index]] = resid
            out_dict[gain.name[:-3]] = sse_alignment_row

        # Write to file
        with open(output_alignment, "w") as f:
            for key in out_dict.keys():
                f.write(f">{key}\n{''.join(out_dict[key])}\n")
        print(f"Done transforming alignment {input_alignment} to {output_alignment} with SSE data.")

# %%
"""alignment_file = "/home/hildilab/projects/agpcr_nom/batch_out_test/big_mafft.fa"
quality_file = "/home/hildilab/projects/agpcr_nom/batch_out_test/big_mafft.jal"
fasta_file = "/home/hildilab/projects/agpcr_nom/batch_files/batch_60.fa"
stride_folder = f"{pdb_folder}/stride_files"
quality = sse_func.read_quality(quality_file)
gps_minus_one = 19258
aln_cutoff = 19822
sequences = sse_func.read_multi_seq(fasta_file)
print(len(sequences))
stride_files = glob.glob("/home/hildilab/projects/agpcr_nom/batch_out_test/stride_files/*")
print(len(stride_files))"""
# Out:
# 'alignment_file = "/home/hildilab/projects/agpcr_nom/batch_out_test/big_mafft.fa"\nquality_file = "/home/hildilab/projects/agpcr_nom/batch_out_test/big_mafft.jal"\nfasta_file = "/home/hildilab/projects/agpcr_nom/batch_files/batch_60.fa"\nstride_folder = f"{pdb_folder}/stride_files"\nquality = sse_func.read_quality(quality_file)\ngps_minus_one = 19258\naln_cutoff = 19822\nsequences = sse_func.read_multi_seq(fasta_file)\nprint(len(sequences))\nstride_files = glob.glob("/home/hildilab/projects/agpcr_nom/batch_out_test/stride_files/*")\nprint(len(stride_files))'

# %%
"""filterCollection = FilterCollection(alignment_file,
                                   aln_cutoff = 19822,
                                   quality = quality,
                                   gps_index = gps_minus_one,
                                   stride_files = stride_files,
                                   sequences = sequences)"""
# Out:
# 'filterCollection = FilterCollection(alignment_file,\n                                   aln_cutoff = 19822,\n                                   quality = quality,\n                                   gps_index = gps_minus_one,\n                                   stride_files = stride_files,\n                                   sequences = sequences)'

# %%
#filterCollection.write_filtered(savename="test.fa", bool_mask = filterCollection.valid_gps, write_mode='w')

# %%
def batch_filter_seqs(arg_item):
                   # [sequences,      # A number of sequences as tuple instances
                   #  stride_folder,  # A folder containing ALL stride files
                   #   output_prefix,  # A prefix for individual file identification
                   #   alignment_file, # The big (initial) alignment file
                   #   quality,        # The corr. parsed quality for BLOSUM62 score
                   #   aln_cutoff,     # the left-most column (19822 for big_mafft.fa)
                   #   gps_minus_one,  # The column index of GPS-1 (zero-indexed! 19258 big_mafft)
                   #   ]
    sequences, stride_folder, output_prefix, alignment_file, quality, aln_cutoff, gps_minus_one, alignment_dict = arg_item
    # Parallelizable version of filtering sequences and models via FilterCollection
    # This should create separate files for each valid, fragment and no-SD group
    # These files should then be grouped together
    # The batch size is arbitrary and is considered the number of sequences passed
    
    # Output: Profiles; 4 Text files (valid, fragment, invalidGPS, invalid)
    filteredBatch = FilterCollection(alignment_file,
                                   aln_cutoff = aln_cutoff,
                                   quality = quality,
                                   gps_index = gps_minus_one,
                                   stride_files = stride_files,
                                   sequences = sequences,
                                   alignment_dict = alignment_dict)
    outpath = "/home/flo/projects/agpcr_nom/all_gps_profiles"
    
    for Gain in filteredBatch.collection:
        if Gain:
            Gain.plot_profile(outdir=outpath)
        
    suffixes = ["gain", 
                "fragments", 
                "noncons_gps", 
                "invalid"]
    masks = [np.logical_and(filteredBatch.valid_gps, filteredBatch.valid_subdomain),
              np.logical_not(filteredBatch.valid_subdomain),
              np.logical_not(filteredBatch.valid_gps),
              np.logical_not(np.logical_and(filteredBatch.valid_gps, filteredBatch.valid_subdomain))]
    # write four separate files, matching each criterion
    for k in range(4):
        filteredBatch.write_filtered(savename=f"{outpath}/{output_prefix}_{suffixes[k]}.fa", 
                                     bool_mask = masks[k],
                                     write_mode = 'w')
    return None

def compile_fastas(prefixes, out_prefix):
    # Compiles the fasta files together to construct one large file containing the sequences
    # satisfying each criterion in the 2x2 matrix
    # we want to have the GAIN sequence only that is output by the write_filtered() func.
    
    # Gather all files:
    suffixes = ["gain", 
                "fragments", 
                "noncons_gps", 
                "invalid"]
    all_files = np.asarray([glob.glob(f"{prefix}*fa") for prefix in prefixes]).flatten()
    
    for suffix in suffixes:
        sub_list = [f for f in all_files if suffix in f.split("_")[-1]]
        print(f"Sublist constructed for {suffix = } containing {len(sub_list)} files.")
        with open(f"{out_prefix}_{suffixes}.fa", "w") as all_file:
            for file in sublist:
                with open(file, "w") as f:
                    data = f.read()
                all_file.write(data)

# %%
def run_mp_collection(arg_list, n_threads=10):
    pool = mp.Pool(n_threads)
    pool.map(batch_filter_seqs, arg_list)
    print("Completed mutithreaded filtering.")

def construct_arg_list(batch_sequence_files, 
                       output_folder,
                       stride_folder, 
                       quality, 
                       alignment_file, 
                       aln_cutoff, 
                       gps_minus_one,
                       alignment_dict = None):
    """ each item looks like this:
        sequences, \ 
        stride_folder, \
        output_prefix, \
        alignment_file, \
        quality, \
        aln_cutoff, \
        gps_minus_one = arg_item"""
    # static : stride_folder, quality, alignment_file, aln_cutoff, gps_minus_one
    # flexible : sequences, output_prefix
    arg_list = []
    #
    for idx, sequence_file in enumerate(batch_sequence_files):
        
        index_string = str(idx)
        sequences = sse_func.read_multi_seq(sequence_file)
        output_prefix = f"{output_folder}_{index_string.zfill(3)}"
        item = [sequences, 
                stride_folder, 
                output_prefix, 
                alignment_file, 
                quality, 
                aln_cutoff, 
                gps_minus_one,
                alignment_dict]
        
        arg_list.append(item)
    
    print(f"[NOTE] : Compiled list of arguments for multithreaded filtering"
          f" containing {len(arg_list)} items.")
    return arg_list

# %%
batch_sequence_files = glob.glob("/home/flo/projects/agpcr_nom/all_gp*/batch_*.fa")
output_folder = "all_gps_gain_domains"

alignment_file = "/home/flo/projects/agpcr_nom/big_mafft.fa"
quality_file = "/home/flo/projects/agpcr_nom/big_mafft.jal"
stride_folder = "/home/flo/projects/agpcr_nom/all_gps_stride"
quality = sse_func.read_quality(quality_file)
gps_minus_one = 19258
aln_cutoff = 19822
stride_files = glob.glob("/home/flo/projects/agpcr_nom/all_gps_stride/*")
alignment_dict = sse_func.read_alignment(alignment_file, aln_cutoff)
print(len(stride_files))
print(len(batch_sequence_files))
#print(quality)
#sequences = sse_func.read_multi_seq(fasta_file)

arg_list = construct_arg_list(batch_sequence_files, 
                       output_folder,
                       stride_folder, 
                       quality, 
                       alignment_file, 
                       aln_cutoff, 
                       gps_minus_one,
                       alignment_dict)
print(len(test_arg))
for arg in test_arg:
    print("Next ITEM")
    for item in arg:
        try:print(len(item))
        except: print(item)
# Out:
# 14773
# 465
# [NOTE] : Compiled list of arguments for multithreaded filtering containing 465 items.
# 10
# Next ITEM
# 75
# 43
# 24
# 41
# 19822
# 19822
# 19258
# 14792
# Next ITEM
# 75
# 43
# 24
# 41
# 19822
# 19822
# 19258
# 14792
# Next ITEM
# 75
# 43
# 24
# 41
# 19822
# 19822
# 19258
# 14792
# Next ITEM
# 75
# 43
# 24
# 41
# 19822
# 19822
# 19258
# 14792
# Next ITEM
# 75
# 43
# 24
# 41
# 19822
# 19822
# 19258
# 14792
# Next ITEM
# 75
# 43
# 24
# 41
# 19822
# 19822
# 19258
# 14792
# Next ITEM
# 75
# 43
# 24
# 41
# 19822
# 19822
# 19258
# 14792
# Next ITEM
# 75
# 43
# 24
# 41
# 19822
# 19822
# 19258
# 14792
# Next ITEM
# 75
# 43
# 24
# 41
# 19822
# 19822
# 19258
# 14792
# Next ITEM
# 75
# 43
# 24
# 41
# 19822
# 19822
# 19258
# 14792

# %%
#batch_filter_seqs(test_arg[0])
run_mp_collection(arg_list, n_threads=4)
# Out:
# Found sequences object.
#
# Initializing GainDomain Object.
#  None A0A2D0SQF4-A0A2D0SQF4_ICTPU-mucin-2-likeisoformX2-Ictalurus_punctatus
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 85(new variant)
# DEBUG: Getting alignment indices with: A0A2D0SQF4-A0A2D0SQF4_ICTPU-mucin-2-likeisoformX2-Ictalurus_punctatus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 256, start = 531
# DEBUG: self.indices = [255, 256, 257]
#
# Initializing GainDomain Object.
#  None A0A2D0SQF8-A0A2D0SQF8_ICTPU-mucin-2-likeisoformX1-Ictalurus_punctatus
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 85(new variant)
# DEBUG: Getting alignment indices with: A0A2D0SQF8-A0A2D0SQF8_ICTPU-mucin-2-likeisoformX1-Ictalurus_punctatus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 256, start = 531
# DEBUG: self.indices = [255, 256, 257]
#
# Initializing GainDomain Object.
#  None A0A2D0SQM0-A0A2D0SQM0_ICTPU-AGRF5-likeisoformX5-Ictalurus_punctatus
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 86(new variant)
# DEBUG: Getting alignment indices with: A0A2D0SQM0-A0A2D0SQM0_ICTPU-AGRF5-likeisoformX5-Ictalurus_punctatus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 256, start = 531
# DEBUG: self.indices = [255, 256, 257]
#
# Initializing GainDomain Object.
#  None A0A2D0SQM5-A0A2D0SQM5_ICTPU-AGRF5-likeisoformX10-Ictalurus_punctatus
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 86(new variant)
# DEBUG: Getting alignment indices with: A0A2D0SQM5-A0A2D0SQM5_ICTPU-AGRF5-likeisoformX10-Ictalurus_punctatus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 256, start = 531
# DEBUG: self.indices = [255, 256, 257]
#
# Initializing GainDomain Object.
#  None A0A2I0LUM3-A0A2I0LUM3_COLLI-AGRL3-Columba_livia
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: Getting alignment indices with: A0A2I0LUM3-A0A2I0LUM3_COLLI-AGRL3-Columba_livia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 307, start = 480
# DEBUG: self.indices = [306, 307, 308]
#
# Initializing GainDomain Object.
#  None A0A2I0LZF5-A0A2I0LZF5_COLLI-AGRV1-Columba_livia
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 71(new variant)
# DEBUG: Getting alignment indices with: A0A2I0LZF5-A0A2I0LZF5_COLLI-AGRV1-Columba_livia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 269, start = 518
# DEBUG: self.indices = [268, 269, 270]
#
# Initializing GainDomain Object.
#  None A0A2I0ME39-A0A2I0ME39_COLLI-AGRL2,transcriptvariantX1-Columba_livia
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 106(new variant)
# DEBUG: Getting alignment indices with: A0A2I0ME39-A0A2I0ME39_COLLI-AGRL2,transcriptvariantX1-Columba_livia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 305, start = 482
# DEBUG: self.indices = [304, 305, 306]
#
# Initializing GainDomain Object.
#  None A0A2I0ME41-A0A2I0ME41_COLLI-AGRL2,transcriptvariantX3-Columba_livia
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 106(new variant)
# DEBUG: Getting alignment indices with: A0A2I0ME41-A0A2I0ME41_COLLI-AGRL2,transcriptvariantX3-Columba_livia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 305, start = 482
# DEBUG: self.indices = [304, 305, 306]
#
# Initializing GainDomain Object.
#  None A0A2I0ME47-A0A2I0ME47_COLLI-AGRL2,transcriptvariantX4-Columba_livia
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 98(new variant)
# DEBUG: Getting alignment indices with: A0A2I0ME47-A0A2I0ME47_COLLI-AGRL2,transcriptvariantX4-Columba_livia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 292, start = 495
# DEBUG: self.indices = [291, 292, 293]
#
# Initializing GainDomain Object.
#  None A0A2I0ME50-A0A2I0ME50_COLLI-AGRL2,transcriptvariantX5-Columba_livia
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 106(new variant)
# DEBUG: Getting alignment indices with: A0A2I0ME50-A0A2I0ME50_COLLI-AGRL2,transcriptvariantX5-Columba_livia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 305, start = 482
# DEBUG: self.indices = [304, 305, 306]
#
# Initializing GainDomain Object.
#  None A0A2I0MHB3-A0A2I0MHB3_COLLI-Cadherin,EGFLAGseven-passG-typereceptor1-Columba_livia
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 96(new variant)
# DEBUG: Getting alignment indices with: A0A2I0MHB3-A0A2I0MHB3_COLLI-Cadherin,EGFLAGseven-passG-typereceptor1-Columba_livia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 340, start = 447
# DEBUG: self.indices = [339, 340, 341]
#
# Initializing GainDomain Object.
#  None A0A2I0MLD0-A0A2I0MLD0_COLLI-AGRG2-Columba_livia
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 44(new variant)
# DEBUG: Getting alignment indices with: A0A2I0MLD0-A0A2I0MLD0_COLLI-AGRG2-Columba_livia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 239, start = 548
# DEBUG: self.indices = [238, 239, 240]
#
# Initializing GainDomain Object.
#  None A0A2I0MTF5-A0A2I0MTF5_COLLI-AGRG6-Columba_livia
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 59(new variant)
# DEBUG: Getting alignment indices with: A0A2I0MTF5-A0A2I0MTF5_COLLI-AGRG6-Columba_livia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 255, start = 532
# DEBUG: self.indices = [254, 255, 256]
#
# Initializing GainDomain Object.
#  None A0A2I0MU76-A0A2I0MU76_COLLI-AGRF5,transcriptvariantX1-Columba_livia
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 90(new variant)
# WARNING: There are still secondary-structure associated residues within the Subdomain connecting loop. Please retry with different parameters.
# DEBUG: Getting alignment indices with: A0A2I0MU76-A0A2I0MU76_COLLI-AGRF5,transcriptvariantX1-Columba_livia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 263, start = 524
# DEBUG: self.indices = [262, 263, 264]
#
# Initializing GainDomain Object.
#  None A0A2I0TKP4-A0A2I0TKP4_LIMLA-Uncharacterizedprotein-Limosa_lapponica_baueri.
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 75(new variant)
# WARNING: There are still secondary-structure associated residues within the Subdomain connecting loop. Please retry with different parameters.
# DEBUG: Getting alignment indices with: A0A2I0TKP4-A0A2I0TKP4_LIMLA-Uncharacterizedprotein-Limosa_lapponica_baueri., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 275, start = 512
# DEBUG: self.indices = [274, 275, 276]
#
# Initializing GainDomain Object.
#  None A0A2I0U3M0-A0A2I0U3M0_LIMLA-Uncharacterizedprotein-Limosa_lapponica_baueri.
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 59(new variant)
# DEBUG: Getting alignment indices with: A0A2I0U3M0-A0A2I0U3M0_LIMLA-Uncharacterizedprotein-Limosa_lapponica_baueri., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 254, start = 533
# DEBUG: self.indices = [253, 254, 255]
#
# Initializing GainDomain Object.
#  None A0A2I0UQN4-A0A2I0UQN4_LIMLA-Agprotein-coupledreceptorl2isoformx1-Limosa_lapponica_baueri.
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 99(new variant)
# DEBUG: Getting alignment indices with: A0A2I0UQN4-A0A2I0UQN4_LIMLA-Agprotein-coupledreceptorl2isoformx1-Limosa_lapponica_baueri., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 292, start = 495
# DEBUG: self.indices = [291, 292, 293]
#
# Initializing GainDomain Object.
#  None A0A2I2U088-A0A2I2U088_FELCA-AGRG6-Felis_catus
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 57(new variant)
# DEBUG: Getting alignment indices with: A0A2I2U088-A0A2I2U088_FELCA-AGRG6-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 258, start = 529
# DEBUG: self.indices = [257, 258, 259]
#
# Initializing GainDomain Object.
#  None A0A2I2U0D3-A0A2I2U0D3_FELCA-AGRL2-Felis_catus
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 106(new variant)
# DEBUG: Getting alignment indices with: A0A2I2U0D3-A0A2I2U0D3_FELCA-AGRL2-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# Found sequences object.
# DEBUG: minus_one_residue = 306, start = 481
# DEBUG: self.indices = [305, 306, 307]
#
# Initializing GainDomain Object.
#  None A0A663EIR9-A0A663EIR9_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos.
# Initializing GainDomain Object.
#
# None A0A2I2U0N2-A0A2I2U0N2_FELCA-AGRL2-Felis_catus
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 98(new variant)
#
# DEBUG: Getting alignment indices with: A0A663EIR9-A0A663EIR9_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: Getting alignment indices with: A0A2I2U0N2-A0A2I2U0N2_FELCA-AGRL2-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 307, start = 480DEBUG: minus_one_residue = 293, start = 494
#
# DEBUG: self.indices = [306, 307, 308]DEBUG: self.indices = [292, 293, 294]
#
#
# Initializing GainDomain Object.
#
# Initializing GainDomain Object.
#   NoneNone  A0A2I2U5R8-A0A2I2U5R8_FELCA-AGRL3-Felis_catusA0A663EIS9-A0A663EIS9_AQUCH-AGRB2-Aquila_chrysaetos_chrysaetos.
#
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: Getting alignment indices with: A0A2I2U5R8-A0A2I2U5R8_FELCA-AGRL3-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 97(new variant)
#
# DEBUG: Getting alignment indices with: A0A663EIS9-A0A663EIS9_AQUCH-AGRB2-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 286, start = 501
# DEBUG: self.indices = [285, 286, 287]DEBUG: minus_one_residue = 307, start = 480
#
# DEBUG: self.indices = [306, 307, 308]
#
# Initializing GainDomain Object.
#  None
# Initializing GainDomain Object.
#  None A0A2I2U7T9-A0A2I2U7T9_FELCA-AGRB2-Felis_catus A0A663EIV8-A0A663EIV8_AQUCH-AGRB2-Aquila_chrysaetos_chrysaetos.
#
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 97(new variant)Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 97(new variant)
#
# DEBUG: Getting alignment indices with: A0A663EIV8-A0A663EIV8_AQUCH-AGRB2-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>DEBUG: Getting alignment indices with: A0A2I2U7T9-A0A2I2U7T9_FELCA-AGRB2-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# DEBUG: minus_one_residue = 286, start = 501
# DEBUG: self.indices = [285, 286, 287]
# DEBUG: minus_one_residue = 323, start = 464
# DEBUG: self.indices = [322, 323, 324]
#
# Initializing GainDomain Object.
#  None A0A663EIW8-A0A663EIW8_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos.
#
# Initializing GainDomain Object.
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: Getting alignment indices with: A0A663EIW8-A0A663EIW8_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>None
#  A0A2I2UB34-A0A2I2UB34_FELCA-AGRL1-Felis_catus
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 105(new variant)
# DEBUG: Getting alignment indices with: A0A2I2UB34-A0A2I2UB34_FELCA-AGRL1-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 307, start = 480
# DEBUG: self.indices = [306, 307, 308]
#
# Initializing GainDomain Object.
#  DEBUG: minus_one_residue = 308, start = 479None
# A0A663EIX3-A0A663EIX3_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos.DEBUG: self.indices = [307, 308, 309]
#
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: Getting alignment indices with: A0A663EIX3-A0A663EIX3_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
#  None A0A2I2UL54-A0A2I2UL54_FELCA-AGRL2-Felis_catus
# DEBUG: minus_one_residue = 307, start = 480
# DEBUG: self.indices = [306, 307, 308]
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 106(new variant)
# DEBUG: Getting alignment indices with: A0A2I2UL54-A0A2I2UL54_FELCA-AGRL2-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
#  None A0A663EIX8-A0A663EIX8_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos.
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: Getting alignment indices with: A0A663EIX8-A0A663EIX8_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 306, start = 481
# DEBUG: self.indices = [305, 306, 307]
# DEBUG: minus_one_residue = 307, start = 480
#
# Initializing GainDomain Object.
# DEBUG: self.indices = [306, 307, 308]
# None A0A2I2UPT2-A0A2I2UPT2_FELCA-AGRB2-Felis_catus
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 96(new variant)
# Initializing GainDomain Object.
#
# NoneDEBUG: Getting alignment indices with: A0A2I2UPT2-A0A2I2UPT2_FELCA-AGRB2-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#  A0A663EJ46-A0A663EJ46_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos.
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: Getting alignment indices with: A0A663EJ46-A0A663EJ46_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 323, start = 464
# DEBUG: self.indices = [322, 323, 324]
# DEBUG: minus_one_residue = 307, start = 480
# Initializing GainDomain Object.
#
#  NoneDEBUG: self.indices = [306, 307, 308] A0A2I2US02-A0A2I2US02_FELCA-AGRL3-Felis_catus
#
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: Getting alignment indices with: A0A2I2US02-A0A2I2US02_FELCA-AGRL3-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
#  None A0A663EJ79-A0A663EJ79_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos.
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: minus_one_residue = 307, start = 480
# DEBUG: Getting alignment indices with: A0A663EJ79-A0A663EJ79_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: self.indices = [306, 307, 308]
#
# Initializing GainDomain Object.
#  None A0A2I2UTI9-A0A2I2UTI9_FELCA-AGRF5-Felis_catusDEBUG: minus_one_residue = 307, start = 480
#
# DEBUG: self.indices = [306, 307, 308]
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 90(new variant)
# DEBUG: Getting alignment indices with: A0A2I2UTI9-A0A2I2UTI9_FELCA-AGRF5-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
#  None A0A663EJQ3-A0A663EJQ3_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos.
# DEBUG: minus_one_residue = 265, start = 522
# DEBUG: self.indices = [264, 265, 266]
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: Getting alignment indices with: A0A663EJQ3-A0A663EJQ3_AQUCH-AGRL3-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
#  None A0A2I2UVD9-A0A2I2UVD9_FELCA-AGRL2-Felis_catus
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 106(new variant)
# DEBUG: Getting alignment indices with: A0A2I2UVD9-A0A2I2UVD9_FELCA-AGRL2-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 307, start = 480
# DEBUG: self.indices = [306, 307, 308]
# DEBUG: minus_one_residue = 306, start = 481
# DEBUG: self.indices = [305, 306, 307]
# Initializing GainDomain Object.
#
#  None A0A663ENR9-A0A663ENR9_AQUCH-AGRG6-Aquila_chrysaetos_chrysaetos.
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 60(new variant)
# DEBUG: Getting alignment indices with: A0A663ENR9-A0A663ENR9_AQUCH-AGRG6-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# Initializing GainDomain Object.
#
#  None A0A2I2UWE8-A0A2I2UWE8_FELCA-AGRL3-Felis_catus
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: Getting alignment indices with: A0A2I2UWE8-A0A2I2UWE8_FELCA-AGRL3-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>DEBUG: minus_one_residue = 256, start = 531
#
# DEBUG: self.indices = [255, 256, 257]
#
# Initializing GainDomain Object.
#  DEBUG: minus_one_residue = 307, start = 480None
#  A0A663ETC3-A0A663ETC3_AQUCH-CadherinEGFLAGseven-passG-typereceptor1-Aquila_chrysaetos_chrysaetos.DEBUG: self.indices = [306, 307, 308]
#
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 97(new variant)
#
# Initializing GainDomain Object.
# DEBUG: Getting alignment indices with: A0A663ETC3-A0A663ETC3_AQUCH-CadherinEGFLAGseven-passG-typereceptor1-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#  None A0A2I2UZI8-A0A2I2UZI8_FELCA-AGRB2-Felis_catusDEBUG: minus_one_residue = 329, start = 458
#
# DEBUG: self.indices = [328, 329, 330]
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 96(new variant)
# DEBUG: Getting alignment indices with: A0A2I2UZI8-A0A2I2UZI8_FELCA-AGRB2-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# Initializing GainDomain Object.
#
# None  A0A663FF54-A0A663FF54_AQUCH-AGRL1-Aquila_chrysaetos_chrysaetos.DEBUG: minus_one_residue = 323, start = 464
#
# DEBUG: self.indices = [322, 323, 324]
#
# Initializing GainDomain Object.
#  NoneFound Helix boundary with the following characteristics: maxk = 0 helical_counts[maxk] = 104(new variant)
# A0A2I2V4L1-A0A2I2V4L1_FELCA-AGRB3-Felis_catusDEBUG: Getting alignment indices with: A0A663FF54-A0A663FF54_AQUCH-AGRL1-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 97(new variant)
# DEBUG: Getting alignment indices with: A0A2I2V4L1-A0A2I2V4L1_FELCA-AGRB3-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 289, start = 498
# DEBUG: self.indices = [288, 289, 290]
# DEBUG: minus_one_residue = 287, start = 500
# DEBUG: self.indices = [286, 287, 288]
#
# Initializing GainDomain Object.
#  None A0A663FH35-A0A663FH35_AQUCH-CadherinEGFLAGseven-passG-typereceptor3-Aquila_chrysaetos_chrysaetos.
#
# Initializing GainDomain Object.
#  Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 73(new variant)None
# DEBUG: Getting alignment indices with: A0A663FH35-A0A663FH35_AQUCH-CadherinEGFLAGseven-passG-typereceptor3-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# A0A2I2V523-A0A2I2V523_FELCA-AGRL2-Felis_catus
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 106(new variant)
# DEBUG: Getting alignment indices with: A0A2I2V523-A0A2I2V523_FELCA-AGRL2-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 312, start = 475
# DEBUG: self.indices = [311, 312, 313]
# DEBUG: minus_one_residue = 306, start = 481
# Initializing GainDomain Object.
#
# DEBUG: self.indices = [305, 306, 307]
# None A0A663FHW4-A0A663FHW4_AQUCH-CadherinEGFLAGseven-passG-typereceptor3-Aquila_chrysaetos_chrysaetos.
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 91(new variant)
#
# Initializing GainDomain Object.
# DEBUG: Getting alignment indices with: A0A663FHW4-A0A663FHW4_AQUCH-CadherinEGFLAGseven-passG-typereceptor3-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# None A0A2I2Y2R6-A0A2I2Y2R6_GORGO-AGRL1-Gorilla_gorilla_gorilla
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 104(new variant)
# DEBUG: Getting alignment indices with: A0A2I2Y2R6-A0A2I2Y2R6_GORGO-AGRL1-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>DEBUG: minus_one_residue = 338, start = 449
#
# DEBUG: self.indices = [337, 338, 339]
# DEBUG: minus_one_residue = 309, start = 478
# Initializing GainDomain Object.
#
#  DEBUG: self.indices = [308, 309, 310]None
#  A0A663FIF8-A0A663FIF8_AQUCH-AGRL1-Aquila_chrysaetos_chrysaetos.
#
# Initializing GainDomain Object.
#  NoneFound Helix boundary with the following characteristics: maxk = 0 helical_counts[maxk] = 105(new variant)
# A0A2I2Y7F0-A0A2I2Y7F0_GORGO-AGRL2-Gorilla_gorilla_gorilla
# DEBUG: Getting alignment indices with: A0A663FIF8-A0A663FIF8_AQUCH-AGRL1-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 98(new variant)
# DEBUG: Getting alignment indices with: A0A2I2Y7F0-A0A2I2Y7F0_GORGO-AGRL2-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 288, start = 499
# DEBUG: self.indices = [287, 288, 289]
# DEBUG: minus_one_residue = 293, start = 494
# Initializing GainDomain Object.
#
#  DEBUG: self.indices = [292, 293, 294]None
#  A0A663FJ65-A0A663FJ65_AQUCH-CadherinEGFLAGseven-passG-typereceptor3-Aquila_chrysaetos_chrysaetos.
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 93(new variant)
#
# Initializing GainDomain Object.
#  DEBUG: Getting alignment indices with: A0A663FJ65-A0A663FJ65_AQUCH-CadherinEGFLAGseven-passG-typereceptor3-Aquila_chrysaetos_chrysaetos., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>None
#  A0A2I2Y9M5-A0A2I2Y9M5_GORGO-AGRL3-Gorilla_gorilla_gorilla
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 105(new variant)
# DEBUG: minus_one_residue = 326, start = 461DEBUG: Getting alignment indices with: A0A2I2Y9M5-A0A2I2Y9M5_GORGO-AGRL3-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# DEBUG: self.indices = [325, 326, 327]
# DEBUG: minus_one_residue = 307, start = 480
#
# Initializing GainDomain Object.
#  DEBUG: self.indices = [306, 307, 308]None A0A663M824-A0A663M824_ATHCN-CadherinEGFLAGseven-passG-typereceptor3-Athene_cunicularia
#
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 95(new variant)
# DEBUG: Getting alignment indices with: A0A663M824-A0A663M824_ATHCN-CadherinEGFLAGseven-passG-typereceptor3-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
#  None A0A2I2YCA1-A0A2I2YCA1_GORGO-AGRL3-Gorilla_gorilla_gorilla
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 105(new variant)DEBUG: minus_one_residue = 333, start = 454
# DEBUG: Getting alignment indices with: A0A2I2YCA1-A0A2I2YCA1_GORGO-AGRL3-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: self.indices = [332, 333, 334]
#
#
# Initializing GainDomain Object.
# DEBUG: minus_one_residue = 307, start = 480
# DEBUG: self.indices = [306, 307, 308]
# None
# Initializing GainDomain Object.
# A0A663M924-A0A663M924_ATHCN-AGRG6-Athene_cunicularia None
#  Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 59(new variant)A0A2I2YS18-A0A2I2YS18_GORGO-AGRL2-Gorilla_gorilla_gorilla
# DEBUG: Getting alignment indices with: A0A663M924-A0A663M924_ATHCN-AGRG6-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 106(new variant)
# DEBUG: Getting alignment indices with: A0A2I2YS18-A0A2I2YS18_GORGO-AGRL2-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 254, start = 533DEBUG: minus_one_residue = 307, start = 480
#
# DEBUG: self.indices = [306, 307, 308]DEBUG: self.indices = [253, 254, 255]
#
#
# Initializing GainDomain Object.
#
# Initializing GainDomain Object.
#   NoneNone  A0A663M951-A0A663M951_ATHCN-AGRG6-Athene_cuniculariaA0A2I2YTV0-A0A2I2YTV0_GORGO-AGRL2-Gorilla_gorilla_gorilla
#
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 59(new variant)
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 106(new variant)DEBUG: Getting alignment indices with: A0A663M951-A0A663M951_ATHCN-AGRG6-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# DEBUG: minus_one_residue = 254, start = 533
# DEBUG: self.indices = [253, 254, 255]DEBUG: Getting alignment indices with: A0A2I2YTV0-A0A2I2YTV0_GORGO-AGRL2-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
#
# Initializing GainDomain Object.
#  DEBUG: minus_one_residue = 307, start = 480None
#  DEBUG: self.indices = [306, 307, 308]
# A0A663M958-A0A663M958_ATHCN-AGRG6-Athene_cunicularia
# Found Helix boundary with the following characteristics: maxk = 8 helical_counts[maxk] = 59(new variant)
#
# Initializing GainDomain Object.
# DEBUG: Getting alignment indices with: A0A663M958-A0A663M958_ATHCN-AGRG6-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# None A0A2I2YWH2-A0A2I2YWH2_GORGO-AGRL3-Gorilla_gorilla_gorilla
# DEBUG: minus_one_residue = 255, start = 532
# DEBUG: self.indices = [254, 255, 256]
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 105(new variant)
# DEBUG: Getting alignment indices with: A0A2I2YWH2-A0A2I2YWH2_GORGO-AGRL3-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
#  None A0A663MDG4-A0A663MDG4_ATHCN-AGRL2-Athene_cunicularia
# DEBUG: minus_one_residue = 307, start = 480Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 107(new variant)
#
# DEBUG: self.indices = [306, 307, 308]DEBUG: Getting alignment indices with: A0A663MDG4-A0A663MDG4_ATHCN-AGRL2-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
#
# Initializing GainDomain Object.
#  None A0A2I2YYL5-A0A2I2YYL5_GORGO-AGRB2-Gorilla_gorilla_gorillaDEBUG: minus_one_residue = 305, start = 482
#
# DEBUG: self.indices = [304, 305, 306]
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 97(new variant)
# DEBUG: Getting alignment indices with: A0A2I2YYL5-A0A2I2YYL5_GORGO-AGRB2-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
#  None A0A663MQB6-A0A663MQB6_ATHCN-AGRL3-Athene_cunicularia
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: Getting alignment indices with: A0A663MQB6-A0A663MQB6_ATHCN-AGRL3-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>DEBUG: minus_one_residue = 322, start = 465
#
# DEBUG: self.indices = [321, 322, 323]
#
# Initializing GainDomain Object.
#  None A0A2I2YZB3-A0A2I2YZB3_GORGO-AGRL3-Gorilla_gorilla_gorilla
# Found sequences object.
# DEBUG: minus_one_residue = 307, start = 480
# DEBUG: self.indices = [306, 307, 308]
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 105(new variant)
#
# Initializing GainDomain Object.
# DEBUG: Getting alignment indices with: A0A2I2YZB3-A0A2I2YZB3_GORGO-AGRL3-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
#  None A0A663MSP5-A0A663MSP5_ATHCN-AGRL3-Athene_cunicularia
#  None A0A6I9MIZ0-A0A6I9MIZ0_PERMB-AGRF1isoformX1-Peromyscus_maniculatus_bairdii
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: Getting alignment indices with: A0A663MSP5-A0A663MSP5_ATHCN-AGRL3-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>DEBUG: minus_one_residue = 307, start = 480
#
# DEBUG: self.indices = [306, 307, 308]
# Found Helix boundary with the following characteristics: maxk = 10 helical_counts[maxk] = 89(new variant)
# DEBUG: Getting alignment indices with: A0A6I9MIZ0-A0A6I9MIZ0_PERMB-AGRF1isoformX1-Peromyscus_maniculatus_bairdii, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
#  None A0A2I2Z070-A0A2I2Z070_GORGO-AGRL2-Gorilla_gorilla_gorillaDEBUG: minus_one_residue = 307, start = 480
# DEBUG: self.indices = [306, 307, 308]
# DEBUG: minus_one_residue = 261, start = 299
# DEBUG: self.indices = [260, 261, 262]
#
#
# Initializing GainDomain Object.
#
# Initializing GainDomain Object.
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 106(new variant) None
#  DEBUG: Getting alignment indices with: A0A2I2Z070-A0A2I2Z070_GORGO-AGRL2-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# None A0A663MSQ2-A0A663MSQ2_ATHCN-AGRL3-Athene_cunicularia
# A0A6J0CN99-A0A6J0CN99_PERMB-AGRF1isoformX3-Peromyscus_maniculatus_bairdiiDEBUG: minus_one_residue = 307, start = 480Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
#
# DEBUG: self.indices = [306, 307, 308]DEBUG: Getting alignment indices with: A0A663MSQ2-A0A663MSQ2_ATHCN-AGRL3-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
#
# Found Helix boundary with the following characteristics: maxk = 10 helical_counts[maxk] = 89(new variant)
# Initializing GainDomain Object.
#
# DEBUG: Getting alignment indices with: A0A6J0CN99-A0A6J0CN99_PERMB-AGRF1isoformX3-Peromyscus_maniculatus_bairdii, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# None A0A2I2Z089-A0A2I2Z089_GORGO-AGRG4-Gorilla_gorilla_gorilla
# DEBUG: minus_one_residue = 307, start = 480
# DEBUG: self.indices = [306, 307, 308]
# DEBUG: minus_one_residue = 261, start = 299
# DEBUG: self.indices = [260, 261, 262]
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 64(new variant)
#
# Initializing GainDomain Object.
# WARNING: There are still secondary-structure associated residues within the Subdomain connecting loop. Please retry with different parameters.
# Initializing GainDomain Object.
#
#  DEBUG: Getting alignment indices with: A0A2I2Z089-A0A2I2Z089_GORGO-AGRG4-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>NoneNone
#   A0A6P3VXV3-A0A6P3VXV3_CLUHA-AGRD1isoformX2-Clupea_harengus
# A0A663MSW3-A0A663MSW3_ATHCN-AGRL3-Athene_cunicularia
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 55(new variant)
# DEBUG: Getting alignment indices with: A0A6P3VXV3-A0A6P3VXV3_CLUHA-AGRD1isoformX2-Clupea_harengus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: Getting alignment indices with: A0A663MSW3-A0A663MSW3_ATHCN-AGRL3-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 270, start = 517
# DEBUG: self.indices = [269, 270, 271]
# DEBUG: minus_one_residue = 325, start = 235
# DEBUG: self.indices = [324, 325, 326]
#
# Initializing GainDomain Object.
#  None DEBUG: minus_one_residue = 307, start = 480A0A2I2ZDM2-A0A2I2ZDM2_GORGO-AGRL3-Gorilla_gorilla_gorilla
#
# DEBUG: self.indices = [306, 307, 308]
#
# Initializing GainDomain Object.
#  Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 105(new variant)None
# A0A7K9BF27-A0A7K9BF27_DRONO-AGRA3protein-Dromaius_novaehollandiae
# DEBUG: Getting alignment indices with: A0A2I2ZDM2-A0A2I2ZDM2_GORGO-AGRL3-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# Initializing GainDomain Object.
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 85(new variant)
#
#  DEBUG: Getting alignment indices with: A0A7K9BF27-A0A7K9BF27_DRONO-AGRA3protein-Dromaius_novaehollandiae, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>None
#  A0A663MSX8-A0A663MSX8_ATHCN-AGRL3-Athene_cunicularia
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 104(new variant)
# DEBUG: minus_one_residue = 307, start = 480DEBUG: Getting alignment indices with: A0A663MSX8-A0A663MSX8_ATHCN-AGRL3-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>DEBUG: minus_one_residue = 327, start = 233
#
# DEBUG: self.indices = [306, 307, 308]
# DEBUG: self.indices = [326, 327, 328]
#
#
# Initializing GainDomain Object.
# DEBUG: minus_one_residue = 307, start = 480
# Initializing GainDomain Object.
#
#   NoneDEBUG: self.indices = [306, 307, 308]None A0A2I2ZFY4-A0A2I2ZFY4_GORGO-AGRL2-Gorilla_gorilla_gorilla
#
# A0A7L0TQ58-A0A7L0TQ58_CHOAC-AGRA3protein-Chordeiles_acutipennis
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 86(new variant)Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 106(new variant)
#
# DEBUG: Getting alignment indices with: A0A2I2ZFY4-A0A2I2ZFY4_GORGO-AGRL2-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>DEBUG: Getting alignment indices with: A0A7L0TQ58-A0A7L0TQ58_CHOAC-AGRA3protein-Chordeiles_acutipennis, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
#
# Initializing GainDomain Object.
#  None DEBUG: minus_one_residue = 306, start = 481DEBUG: minus_one_residue = 327, start = 233A0A663MTE6-A0A663MTE6_ATHCN-AGRL3-Athene_cunicularia
#
#
# DEBUG: self.indices = [326, 327, 328]DEBUG: self.indices = [305, 306, 307]
#
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 96(new variant)
#
# Initializing GainDomain Object.
#  DEBUG: Getting alignment indices with: A0A663MTE6-A0A663MTE6_ATHCN-AGRL3-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>None
#  A0A2I2ZG69-A0A2I2ZG69_GORGO-AGRB2-Gorilla_gorilla_gorilla
# Initializing GainDomain Object.
#
#  None A0A7L1HT18-A0A7L1HT18_9CHAR-AGRA3protein-Nycticryphes_semicollaris.Found Helix boundary with the following characteristics: maxk = 8 helical_counts[maxk] = 97(new variant)
#
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 86(new variant)DEBUG: minus_one_residue = 294, start = 493
#
# DEBUG: self.indices = [293, 294, 295]DEBUG: Getting alignment indices with: A0A7L1HT18-A0A7L1HT18_9CHAR-AGRA3protein-Nycticryphes_semicollaris., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>DEBUG: Getting alignment indices with: A0A2I2ZG69-A0A2I2ZG69_GORGO-AGRB2-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
#
#
# Initializing GainDomain Object.
#  NoneDEBUG: minus_one_residue = 322, start = 465
# A0A663N8E4-A0A663N8E4_ATHCN-AGRV1-Athene_cuniculariaDEBUG: minus_one_residue = 327, start = 233
#
# DEBUG: self.indices = [321, 322, 323]
# DEBUG: self.indices = [326, 327, 328]Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 71(new variant)
# DEBUG: Getting alignment indices with: A0A663N8E4-A0A663N8E4_ATHCN-AGRV1-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
#
#  None A0A2I2ZGX8-A0A2I2ZGX8_GORGO-AGRB2-Gorilla_gorilla_gorilla
# DEBUG: minus_one_residue = 268, start = 519
# DEBUG: self.indices = [267, 268, 269]
#
# Initializing GainDomain Object.
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 97(new variant)
# None A0A0A0MXC8-A0A0A0MXC8_PAPAN-AGRE1-Papio_anubis
#
# Initializing GainDomain Object.
# DEBUG: Getting alignment indices with: A0A2I2ZGX8-A0A2I2ZGX8_GORGO-AGRB2-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'> None
#  Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 66(new variant)A0A663N959-A0A663N959_ATHCN-CadherinEGFLAGseven-passG-typereceptor1-Athene_cunicularia
#
# DEBUG: Getting alignment indices with: A0A0A0MXC8-A0A0A0MXC8_PAPAN-AGRE1-Papio_anubis, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 92(new variant)
# DEBUG: Getting alignment indices with: A0A663N959-A0A663N959_ATHCN-CadherinEGFLAGseven-passG-typereceptor1-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 322, start = 465
# DEBUG: self.indices = [321, 322, 323]DEBUG: minus_one_residue = 260, start = 301
#
# DEBUG: self.indices = [259, 260, 261]
#
# Initializing GainDomain Object.
# DEBUG: minus_one_residue = 330, start = 457 None
#  DEBUG: self.indices = [329, 330, 331]
# Initializing GainDomain Object.
# A0A2I2ZHS1-A0A2I2ZHS1_GORGO-AGRG6-Gorilla_gorilla_gorilla
#
#  NoneFound Helix boundary with the following characteristics: maxk = 8 helical_counts[maxk] = 59(new variant)
# A0A2I3LRM6-A0A2I3LRM6_PAPAN-AGRE1-Papio_anubisDEBUG: Getting alignment indices with: A0A2I2ZHS1-A0A2I2ZHS1_GORGO-AGRG6-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
#
# Initializing GainDomain Object.
#  None A0A663NAR3-A0A663NAR3_ATHCN-AGRV1-Athene_cuniculariaFound Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 66(new variant)
#
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 71(new variant)DEBUG: Getting alignment indices with: A0A2I3LRM6-A0A2I3LRM6_PAPAN-AGRE1-Papio_anubis, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>DEBUG: minus_one_residue = 260, start = 527
#
# DEBUG: self.indices = [259, 260, 261]
#
# DEBUG: Getting alignment indices with: A0A663NAR3-A0A663NAR3_ATHCN-AGRV1-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
#  NoneDEBUG: minus_one_residue = 260, start = 301 A0A2I2ZJJ8-A0A2I2ZJJ8_GORGO-AGRG6-Gorilla_gorilla_gorilla
# DEBUG: minus_one_residue = 269, start = 518
# DEBUG: self.indices = [268, 269, 270]
# Found Helix boundary with the following characteristics: maxk = 8 helical_counts[maxk] = 59(new variant)DEBUG: self.indices = [259, 260, 261]
#
#
#
# Initializing GainDomain Object.
#  DEBUG: Getting alignment indices with: A0A2I2ZJJ8-A0A2I2ZJJ8_GORGO-AGRG6-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>None
#
# Initializing GainDomain Object.
#  None A0A2K5L209-A0A2K5L209_CERAT-AGRD1-Cercocebus_atys
#  A0A663NBU2-A0A663NBU2_ATHCN-CadherinEGFLAGseven-passG-typereceptor1-Athene_cunicularia
# DEBUG: minus_one_residue = 260, start = 527Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 77(new variant)
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 97(new variant)
# DEBUG: self.indices = [259, 260, 261]
# DEBUG: Getting alignment indices with: A0A663NBU2-A0A663NBU2_ATHCN-CadherinEGFLAGseven-passG-typereceptor1-Athene_cunicularia, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# DEBUG: Getting alignment indices with: A0A2K5L209-A0A2K5L209_CERAT-AGRD1-Cercocebus_atys, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# Initializing GainDomain Object.
#
# NoneDEBUG: minus_one_residue = 329, start = 458 A0A2I2ZKW6-A0A2I2ZKW6_GORGO-AGRL2-Gorilla_gorilla_gorilla
# DEBUG: self.indices = [328, 329, 330]
#
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 106(new variant)
# DEBUG: Getting alignment indices with: A0A2I2ZKW6-A0A2I2ZKW6_GORGO-AGRL2-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
# DEBUG: minus_one_residue = 308, start = 253 None A0A665T6A0-A0A665T6A0_ECHNA-AGRV1-Echeneis_naucrates
#
# DEBUG: self.indices = [307, 308, 309]
# Found Helix boundary with the following characteristics: maxk = 0 helical_counts[maxk] = 70(new variant)
# Initializing GainDomain Object.
#
# DEBUG: minus_one_residue = 306, start = 481
# DEBUG: self.indices = [305, 306, 307]None
#  A0A452IQV5-A0A452IQV5_9SAUR-AGRB3-Gopherus_agassizii
# DEBUG: Getting alignment indices with: A0A665T6A0-A0A665T6A0_ECHNA-AGRV1-Echeneis_naucrates, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>Found Helix boundary with the following characteristics: maxk = 0 helical_counts[maxk] = 96(new variant)
# Initializing GainDomain Object.
#
#
# DEBUG: Getting alignment indices with: A0A452IQV5-A0A452IQV5_9SAUR-AGRB3-Gopherus_agassizii, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#  None A0A2I2ZLL6-A0A2I2ZLL6_GORGO-AGRB2-Gorilla_gorilla_gorilla
# DEBUG: minus_one_residue = 263, start = 518
# DEBUG: minus_one_residue = 286, start = 275DEBUG: self.indices = [262, 263, 264]
#
# DEBUG: self.indices = [285, 286, 287]Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 96(new variant)
#
# DEBUG: Getting alignment indices with: A0A2I2ZLL6-A0A2I2ZLL6_GORGO-AGRB2-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# Initializing GainDomain Object.
#
#  None A0A665TER5-A0A665TER5_ECHNA-AGRV1-Echeneis_naucrates
#
# Initializing GainDomain Object.
#  Found Helix boundary with the following characteristics: maxk = 0 helical_counts[maxk] = 70(new variant)None A0A4W3I9M0-A0A4W3I9M0_CALMI-Uncharacterizedprotein-Callorhinchus_milii
#
# DEBUG: Getting alignment indices with: A0A665TER5-A0A665TER5_ECHNA-AGRV1-Echeneis_naucrates, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>DEBUG: minus_one_residue = 322, start = 465
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 81(new variant)
# DEBUG: self.indices = [321, 322, 323]
#
# DEBUG: Getting alignment indices with: A0A4W3I9M0-A0A4W3I9M0_CALMI-Uncharacterizedprotein-Callorhinchus_milii, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# Initializing GainDomain Object.
#  NoneDEBUG: minus_one_residue = 263, start = 518
# A0A2I2ZSZ8-A0A2I2ZSZ8_GORGO-AGRG4-Gorilla_gorilla_gorillaDEBUG: self.indices = [262, 263, 264]
#
# DEBUG: minus_one_residue = 320, start = 241
# DEBUG: self.indices = [319, 320, 321]
#
# Initializing GainDomain Object.
#  None Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 63(new variant)
# A0A665UX19-A0A665UX19_ECHNA-AGRG2-like-Echeneis_naucratesWARNING: There are still secondary-structure associated residues within the Subdomain connecting loop. Please retry with different parameters.
#
#
# Initializing GainDomain Object.
# DEBUG: Getting alignment indices with: A0A2I2ZSZ8-A0A2I2ZSZ8_GORGO-AGRG4-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 270, start = 517Found Helix boundary with the following characteristics: maxk = 10 helical_counts[maxk] = 58(new variant)
# None DEBUG: Getting alignment indices with: A0A665UX19-A0A665UX19_ECHNA-AGRG2-like-Echeneis_naucrates, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>A0A673TJ69-A0A673TJ69_SURSU-AGRD2-Suricata_suricatta
#
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 95(new variant)
# DEBUG: Getting alignment indices with: A0A673TJ69-A0A673TJ69_SURSU-AGRD2-Suricata_suricatta, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# DEBUG: self.indices = [269, 270, 271]
# DEBUG: minus_one_residue = 265, start = 522
# DEBUG: self.indices = [264, 265, 266]
# Initializing GainDomain Object.
# DEBUG: minus_one_residue = 279, start = 282
#
# NoneDEBUG: self.indices = [278, 279, 280]
#  A0A2I2ZX12-A0A2I2ZX12_GORGO-AGRL2-Gorilla_gorilla_gorilla
# Initializing GainDomain Object.
#
# Initializing GainDomain Object.
#
# None  A0A665V0H9-A0A665V0H9_ECHNA-Uncharacterizedprotein-Echeneis_naucratesNone
#  A0A7K7G3V6-A0A7K7G3V6_ERIRU-AGRA3protein-Erithacus_rubecula
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 98(new variant)
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 85(new variant)
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 86(new variant)DEBUG: Getting alignment indices with: A0A2I2ZX12-A0A2I2ZX12_GORGO-AGRL2-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: Getting alignment indices with: A0A665V0H9-A0A665V0H9_ECHNA-Uncharacterizedprotein-Echeneis_naucrates, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# DEBUG: Getting alignment indices with: A0A7K7G3V6-A0A7K7G3V6_ERIRU-AGRA3protein-Erithacus_rubecula, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 261, start = 526DEBUG: minus_one_residue = 293, start = 494DEBUG: minus_one_residue = 328, start = 233
#
# DEBUG: self.indices = [260, 261, 262]DEBUG: self.indices = [327, 328, 329]
#
#
# DEBUG: self.indices = [292, 293, 294]
#
# Initializing GainDomain Object.
#
# Initializing GainDomain Object.
#   None
# Initializing GainDomain Object.
#  NoneA0A2R9CP18-A0A2R9CP18_PANPA-AGRG2-Pan_paniscus
# None A0A2I2ZXA9-A0A2I2ZXA9_GORGO-AGRB3-Gorilla_gorilla_gorilla
#  A0A665VRC6-A0A665VRC6_ECHNA-AGRL1a-Echeneis_naucratesFound Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 96(new variant)
#
# Found Helix boundary with the following characteristics: maxk = 10 helical_counts[maxk] = 47(new variant)DEBUG: Getting alignment indices with: A0A2I2ZXA9-A0A2I2ZXA9_GORGO-AGRB3-Gorilla_gorilla_gorilla, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
#
# DEBUG: Getting alignment indices with: A0A2R9CP18-A0A2R9CP18_PANPA-AGRG2-Pan_paniscus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 105(new variant)
# DEBUG: Getting alignment indices with: A0A665VRC6-A0A665VRC6_ECHNA-AGRL1a-Echeneis_naucrates, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 240, start = 322
# DEBUG: minus_one_residue = 287, start = 500DEBUG: self.indices = [239, 240, 241]
#
# DEBUG: self.indices = [286, 287, 288]
#
# Initializing GainDomain Object.
#
# Initializing GainDomain Object.
# None DEBUG: minus_one_residue = 303, start = 484
# None  DEBUG: self.indices = [302, 303, 304]A0A3B1KG58-A0A3B1KG58_ASTMX-AGRD2-Astyanax_mexicanus
# A0A2I3H7B3-A0A2I3H7B3_NOMLE-Uncharacterizedprotein-Nomascus_leucogenys
#
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 101(new variant)
# DEBUG: Getting alignment indices with: A0A3B1KG58-A0A3B1KG58_ASTMX-AGRD2-Astyanax_mexicanus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# Initializing GainDomain Object.
#
#  Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 90(new variant)None
#  DEBUG: Getting alignment indices with: A0A2I3H7B3-A0A2I3H7B3_NOMLE-Uncharacterizedprotein-Nomascus_leucogenys, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# A0A665VRD9-A0A665VRD9_ECHNA-AGRL1a-Echeneis_naucrates
# DEBUG: minus_one_residue = 325, start = 237
# DEBUG: self.indices = [324, 325, 326]Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 105(new variant)
# DEBUG: Getting alignment indices with: A0A665VRD9-A0A665VRD9_ECHNA-AGRL1a-Echeneis_naucrates, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# ...
# DEBUG: Getting alignment indices with: A0A7K5I098-A0A7K5I098_CROSL-AGRL4protein-Crotophaga_sulcirostris, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 288, start = 176
# DEBUG: self.indices = [287, 288, 289]
#
# Initializing GainDomain Object.
#  None A0A7K6YWZ1-A0A7K6YWZ1_ALCTO-AGRL4protein-Alca_torda
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 91(new variant)
# DEBUG: Getting alignment indices with: A0A7K6YWZ1-A0A7K6YWZ1_ALCTO-AGRL4protein-Alca_torda, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 288, start = 176
# DEBUG: self.indices = [287, 288, 289]
#
# Initializing GainDomain Object.
#  None A0A7K9HG95-A0A7K9HG95_9AVES-AGRL4protein-Bucco_capensis
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 90(new variant)
# DEBUG: Getting alignment indices with: A0A7K9HG95-A0A7K9HG95_9AVES-AGRL4protein-Bucco_capensis, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 288, start = 176
# DEBUG: self.indices = [287, 288, 289]
#
# Initializing GainDomain Object.
#  None A0A7K9SU85-A0A7K9SU85_9AVES-AGRL4protein-Galbula_dea.
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 95(new variant)
# DEBUG: Getting alignment indices with: A0A7K9SU85-A0A7K9SU85_9AVES-AGRL4protein-Galbula_dea., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 293, start = 171
# DEBUG: self.indices = [292, 293, 294]
#
# Initializing GainDomain Object.
#  None A0A7K9VI91-A0A7K9VI91_ANSSE-AGRL4protein-Anseranas_semipalmata
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 96(new variant)
# DEBUG: Getting alignment indices with: A0A7K9VI91-A0A7K9VI91_ANSSE-AGRL4protein-Anseranas_semipalmata, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 293, start = 171
# DEBUG: self.indices = [292, 293, 294]
#
# Initializing GainDomain Object.
#  None A0A7L0AWR4-A0A7L0AWR4_9AVES-AGRL4protein-Ciconia_maguari.
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 91(new variant)
# DEBUG: Getting alignment indices with: A0A7L0AWR4-A0A7L0AWR4_9AVES-AGRL4protein-Ciconia_maguari., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 288, start = 176
# DEBUG: self.indices = [287, 288, 289]
#
# Initializing GainDomain Object.
#  None A0A7L1T6E1-A0A7L1T6E1_ARAGA-AGRL4protein-Aramus_guarauna
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 92(new variant)
# DEBUG: Getting alignment indices with: A0A7L1T6E1-A0A7L1T6E1_ARAGA-AGRL4protein-Aramus_guarauna, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 291, start = 173
# DEBUG: self.indices = [290, 291, 292]
#
# Initializing GainDomain Object.
#  None A0A7L2HKC4-A0A7L2HKC4_SAGSE-AGRL4protein-Sagittarius_serpentarius
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 90(new variant)
# DEBUG: Getting alignment indices with: A0A7L2HKC4-A0A7L2HKC4_SAGSE-AGRL4protein-Sagittarius_serpentarius, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 288, start = 176
# DEBUG: self.indices = [287, 288, 289]
#
# Initializing GainDomain Object.
#  None A0A7L3FT52-A0A7L3FT52_9GRUI-AGRL4protein-Zapornia_atra.
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 88(new variant)
# DEBUG: Getting alignment indices with: A0A7L3FT52-A0A7L3FT52_9GRUI-AGRL4protein-Zapornia_atra., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 288, start = 176
# DEBUG: self.indices = [287, 288, 289]
#
# Initializing GainDomain Object.
#  None A0A7L4BYG6-A0A7L4BYG6_9AVES-AGRL4protein-Nyctiprogne_leucopyga.
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 90(new variant)
# DEBUG: Getting alignment indices with: A0A7L4BYG6-A0A7L4BYG6_9AVES-AGRL4protein-Nyctiprogne_leucopyga., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 288, start = 176
# DEBUG: self.indices = [287, 288, 289]
#
# Initializing GainDomain Object.
#  None A0A7N6A197-A0A7N6A197_ANATE-AGRL4-Anabas_testudineus
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 101(new variant)
# DEBUG: Getting alignment indices with: A0A7N6A197-A0A7N6A197_ANATE-AGRL4-Anabas_testudineus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 300, start = 164
# DEBUG: self.indices = [299, 300, 301]
#
# Initializing GainDomain Object.
#  None A0A851NQM1-A0A851NQM1_9GALL-AGRL4protein-Penelope_pileata.
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 91(new variant)
# DEBUG: Getting alignment indices with: A0A851NQM1-A0A851NQM1_9GALL-AGRL4protein-Penelope_pileata., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 288, start = 176
# DEBUG: self.indices = [287, 288, 289]
#
# Initializing GainDomain Object.
#  None M4ATZ8-M4ATZ8_XIPMA-Uncharacterizedprotein-Xiphophorus_maculatus
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 95(new variant)
# DEBUG: Getting alignment indices with: M4ATZ8-M4ATZ8_XIPMA-Uncharacterizedprotein-Xiphophorus_maculatus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 296, start = 168
# DEBUG: self.indices = [295, 296, 297]
#
# Initializing GainDomain Object.
#  None W5MQ29-W5MQ29_LEPOC-AGRE5b,duplicate3-Lepisosteus_oculatus
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 53(new variant)
# DEBUG: Getting alignment indices with: W5MQ29-W5MQ29_LEPOC-AGRE5b,duplicate3-Lepisosteus_oculatus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 233, start = 231
# DEBUG: self.indices = [232, 233, 234]
#
# Initializing GainDomain Object.
#  None A0A2I3LWG3-A0A2I3LWG3_PAPAN-AGRE1-Papio_anubis
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 68(new variant)
# DEBUG: Getting alignment indices with: A0A2I3LWG3-A0A2I3LWG3_PAPAN-AGRE1-Papio_anubis, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 261, start = 204
# DEBUG: self.indices = [260, 261, 262]
#
# Initializing GainDomain Object.
#  None A0A2K6B5D3-A0A2K6B5D3_MACNE-AGRE5-Macaca_nemestrina
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 60(new variant)
# DEBUG: Getting alignment indices with: A0A2K6B5D3-A0A2K6B5D3_MACNE-AGRE5-Macaca_nemestrina, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 263, start = 202
# DEBUG: self.indices = [262, 263, 264]
#
# Initializing GainDomain Object.
#  None A0A3B3QZ56-A0A3B3QZ56_9TELE-AGRG2a-Paramormyrops_kingsleyae.
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 53(new variant)
# DEBUG: Getting alignment indices with: A0A3B3QZ56-A0A3B3QZ56_9TELE-AGRG2a-Paramormyrops_kingsleyae., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 259, start = 206
# DEBUG: self.indices = [258, 259, 260]
#
# Initializing GainDomain Object.
#  None A0A3Q2L5M0-A0A3Q2L5M0_HORSE-AGRD1-Equus_caballus
# Found Helix boundary with the following characteristics: maxk = 0 helical_counts[maxk] = 76(new variant)
# DEBUG: Getting alignment indices with: A0A3Q2L5M0-A0A3Q2L5M0_HORSE-AGRD1-Equus_caballus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 308, start = 157
# DEBUG: self.indices = [307, 308, 309]
#
# Initializing GainDomain Object.
#  None A0A5F5XWQ3-A0A5F5XWQ3_FELCA-AGRA3-Felis_catus
# Found Helix boundary with the following characteristics: maxk = 0 helical_counts[maxk] = 82(new variant)
# DEBUG: Getting alignment indices with: A0A5F5XWQ3-A0A5F5XWQ3_FELCA-AGRA3-Felis_catus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 321, start = 144
# DEBUG: self.indices = [320, 321, 322]
#
# Initializing GainDomain Object.
#  None A0A671Z2H0-A0A671Z2H0_SPAAU-AGRL4-Sparus_aurata
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 97(new variant)
# DEBUG: Getting alignment indices with: A0A671Z2H0-A0A671Z2H0_SPAAU-AGRL4-Sparus_aurata, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 297, start = 168
# DEBUG: self.indices = [296, 297, 298]
#
# Initializing GainDomain Object.
#  None A0A673ZNV3-A0A673ZNV3_SALTR-AGRD1-Salmo_trutta
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 34(new variant)
# DEBUG: Getting alignment indices with: A0A673ZNV3-A0A673ZNV3_SALTR-AGRD1-Salmo_trutta, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 276, start = 189
# DEBUG: self.indices = [275, 276, 277]
#
# Initializing GainDomain Object.
#  None A0A6P5C2P3-A0A6P5C2P3_BOSIN-AGRE3-likeisoformX3-Bos_indicus
# Found Helix boundary with the following characteristics: maxk = 6 helical_counts[maxk] = 37(new variant)
# DEBUG: Getting alignment indices with: A0A6P5C2P3-A0A6P5C2P3_BOSIN-AGRE3-likeisoformX3-Bos_indicus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 213, start = 252
# DEBUG: self.indices = [212, 213, 214]
#
# Initializing GainDomain Object.
#  None A0A6P6PCS1-A0A6P6PCS1_CARAU-AGRG2-like-Carassius_auratus
# Found Helix boundary with the following characteristics: maxk = None helical_counts[maxk] = array([[ 8,  2,  0,  0, 12,  5,  1,  2, 19,  2,  1,  4, 10]])(new variant)
# No Subdomain boundaries detected. Possible Fragment found.
# DEBUG: Getting alignment indices with: A0A6P6PCS1-A0A6P6PCS1_CARAU-AGRG2-like-Carassius_auratus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 390, start = 75
# DEBUG: self.indices = [389, 390, 391]
#
# Initializing GainDomain Object.
#  None A0A6P7M5T4-A0A6P7M5T4_BETSP-AGRD2-likeisoformX10-Betta_splendens
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 87(new variant)
# DEBUG: Getting alignment indices with: A0A6P7M5T4-A0A6P7M5T4_BETSP-AGRD2-likeisoformX10-Betta_splendens, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 305, start = 160
# DEBUG: self.indices = [304, 305, 306]
#
# Initializing GainDomain Object.
#  None A0A7K5D686-A0A7K5D686_9TYRA-AGRL4protein-Pachyramphus_minor.
# Found Helix boundary with the following characteristics: maxk = 0 helical_counts[maxk] = 98(new variant)
# DEBUG: Getting alignment indices with: A0A7K5D686-A0A7K5D686_9TYRA-AGRL4protein-Pachyramphus_minor., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 311, start = 154
# DEBUG: self.indices = [310, 311, 312]
#
# Initializing GainDomain Object.
#  None A0A7K8E6K8-A0A7K8E6K8_LEURO-AGRL4protein-Leucopsar_rothschildi
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 85(new variant)
# DEBUG: Getting alignment indices with: A0A7K8E6K8-A0A7K8E6K8_LEURO-AGRL4protein-Leucopsar_rothschildi, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 285, start = 180
# DEBUG: self.indices = [284, 285, 286]
#
# Initializing GainDomain Object.
#  None A0A7L0I694-A0A7L0I694_AREIN-AGRL4protein-Arenaria_interpres
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 87(new variant)
# DEBUG: Getting alignment indices with: A0A7L0I694-A0A7L0I694_AREIN-AGRL4protein-Arenaria_interpres, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 288, start = 177
# DEBUG: self.indices = [287, 288, 289]
#
# Initializing GainDomain Object.
#  None A0A3B4AB58-A0A3B4AB58_9GOBI-Uncharacterizedprotein-Periophthalmus_magnuspinnatus.
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 100(new variant)
# DEBUG: Getting alignment indices with: A0A3B4AB58-A0A3B4AB58_9GOBI-Uncharacterizedprotein-Periophthalmus_magnuspinnatus., /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 302, start = 164
# DEBUG: self.indices = [301, 302, 303]
#
# Initializing GainDomain Object.
#  None A0A6P6NP28-A0A6P6NP28_CARAU-AGRG2-like-Carassius_auratus
# Found Helix boundary with the following characteristics: maxk = None helical_counts[maxk] = array([[11,  5,  0,  2, 19,  2,  1,  4, 10]])(new variant)
# No Subdomain boundaries detected. Possible Fragment found.
# DEBUG: Getting alignment indices with: A0A6P6NP28-A0A6P6NP28_CARAU-AGRG2-like-Carassius_auratus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 390, start = 76
# DEBUG: self.indices = [389, 390, 391]
#
# Initializing GainDomain Object.
#  None A0A7J8BNF9-A0A7J8BNF9_ROUAE-AGRE1-Rousettus_aegyptiacus
# Found Helix boundary with the following characteristics: maxk = 4 helical_counts[maxk] = 67(new variant)
# DEBUG: Getting alignment indices with: A0A7J8BNF9-A0A7J8BNF9_ROUAE-AGRE1-Rousettus_aegyptiacus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 262, start = 204
# DEBUG: self.indices = [261, 262, 263]
#
# Initializing GainDomain Object.
#  None A0A7L4F3M7-A0A7L4F3M7_HIRRU-AGRL4protein-Hirundo_rustica
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 88(new variant)
# DEBUG: Getting alignment indices with: A0A7L4F3M7-A0A7L4F3M7_HIRRU-AGRL4protein-Hirundo_rustica, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 287, start = 179
# DEBUG: self.indices = [286, 287, 288]
#
# Initializing GainDomain Object.
#  None A0A851QVI8-A0A851QVI8_TYCCO-AGRL4protein-Tychaedon_coryphoeus
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 96(new variant)
# DEBUG: Getting alignment indices with: A0A851QVI8-A0A851QVI8_TYCCO-AGRL4protein-Tychaedon_coryphoeus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 311, start = 155
# DEBUG: self.indices = [310, 311, 312]
#
# Initializing GainDomain Object.
#  None E9QMJ5-E9QMJ5_MOUSE-AGRE5-Mus_musculus
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 53(new variant)
# DEBUG: Getting alignment indices with: E9QMJ5-E9QMJ5_MOUSE-AGRE5-Mus_musculus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 242, start = 224
# DEBUG: self.indices = [241, 242, 243]
#
# Initializing GainDomain Object.
#  None G1M4E9-G1M4E9_AILME-AGRE2-Ailuropoda_melanoleuca
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 60(new variant)
# DEBUG: Getting alignment indices with: G1M4E9-G1M4E9_AILME-AGRE2-Ailuropoda_melanoleuca, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 248, start = 218
# DEBUG: self.indices = [247, 248, 249]
#
# Initializing GainDomain Object.
#  None G3VTH8-G3VTH8_SARHA-AGRE5-Sarcophilus_harrisii
# Found Helix boundary with the following characteristics: maxk = 2 helical_counts[maxk] = 54(new variant)
# DEBUG: Getting alignment indices with: G3VTH8-G3VTH8_SARHA-AGRE5-Sarcophilus_harrisii, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 247, start = 219
# DEBUG: self.indices = [246, 247, 248]
#
# Initializing GainDomain Object.
#  None A0A2D0Q6N2-A0A2D0Q6N2_ICTPU-AGRG7isoformX2-Ictalurus_punctatus
# Found Helix boundary with the following characteristics: maxk = 0 helical_counts[maxk] = 73(new variant)
# DEBUG: Getting alignment indices with: A0A2D0Q6N2-A0A2D0Q6N2_ICTPU-AGRG7isoformX2-Ictalurus_punctatus, /home/flo/projects/agpcr_nom/big_mafft.fa <class 'dict'>
# DEBUG: minus_one_residue = 290, start = 177
# DEBUG: self.indices = [289, 290, 291]
# Completed Collection initialitazion of 75 sequences.
# 75 valid proteins were found.
# 73 of which have detected Subdomains.
# 75 of which have detected consensus GPS motifs.
#
# Completed mutithreaded filtering.
